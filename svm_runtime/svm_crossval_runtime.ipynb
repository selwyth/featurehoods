# %%
import pandas as pd
from seaborn import plt
# %matplotlib inline

df = pd.read_csv('svm_crossval_runtime.csv')
df.tail()
# Out:
#     runtime         C     gamma
# 45    221.4  10000000    100000
# 46     44.8  10000000   1000000
# 47     57.3  10000000   1000000
# 48      2.0  10000000  10000000
# 49      1.0  10000000  10000000

# %%
import numpy as np

df['logC'] = df.C.apply(np.log10)
df.head()
# Out:
#    runtime     C     gamma  logC
# 0      1.9  1000  10000000     3
# 1      1.9  1000  10000000     3
# 2      4.1  1000   1000000     3
# 3      4.6  1000   1000000     3
# 4    101.6  1000     10000     3

# %%
import seaborn as sns
sns.lmplot('logC', 'runtime', df, hue='gamma', legend=True)
plt.ylim(0,500)
plt.xlim(2.5, 7)
# sns.regplot('C', 'runtime', df, scatter=True, color = 'gamma', logx=True)
# Out:
# (2.5, 7)
